# %% [markdown]
# <a href="https://colab.research.google.com/github/maliwant/data_viz/blob/main/Quiz4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/My Drive/data-viz'

# %%
data_path = os.path.join(path,'passenger-covid19.xlsx')

# %%
data1_df = pd.read_excel(data_path)
data1_df
# Out:
#    ขนคน/ขนสินค้า โหมดการเดินทาง  ...   พ.ย. 2562   ธ.ค. 2562
# 0      ขนคน (คน)          ทางบก  ...   4559610.0   4840673.0
# 1      ขนคน (คน)          ทางบก  ...         NaN         NaN
# 2      ขนคน (คน)          ทางบก  ...   2450888.0   2516032.0
# 3     ขนคน (คัน)          ทางบก  ...  28325020.0  29615013.0
# 4     ขนคน (คัน)          ทางบก  ...  46996660.0  47294111.0
# 5     ขนคน (คัน)          ทางบก  ...         NaN         NaN
# 6      ขนคน (คน)          ทางบก  ...    108037.0    104032.0
# 7      ขนคน (คน)          ทางบก  ...         NaN         NaN
# 8      ขนคน (คน)          ทางบก  ...  29672244.0  29019427.0
# 9      ขนคน (คน)          ทางบก  ...  25368180.0  24993204.0
# 10    ขนคน (คัน)          ทางบก  ...         NaN         NaN
# 11    ขนคน (คัน)          ทางบก  ...         NaN         NaN
# 12     ขนคน (คน)         ทางน้ำ  ...         NaN         NaN
# 13     ขนคน (คน)         ทางน้ำ  ...    771668.0    766378.0
# ...

# %%
data1_df[data1_df['ยานพาหนะ/ท่า']=='ท่าอากาศยานสุวรรณภูมิ']
# Out:
#    ขนคน/ขนสินค้า โหมดการเดินทาง  ... พ.ย. 2562 ธ.ค. 2562
# 22     ขนคน (คน)       ทางอากาศ  ...  411562.0  458992.0
#
# [1 rows x 18 columns]

# %%
from datetime import datetime

# %%
data1_df.columns = [i.strftime('%Y-%m-%d') if isinstance(i, datetime) else i for i in data1_df.columns]
data1_df
# Out:
#    ขนคน/ขนสินค้า โหมดการเดินทาง  ...   พ.ย. 2562   ธ.ค. 2562
# 0      ขนคน (คน)          ทางบก  ...   4559610.0   4840673.0
# 1      ขนคน (คน)          ทางบก  ...         NaN         NaN
# 2      ขนคน (คน)          ทางบก  ...   2450888.0   2516032.0
# 3     ขนคน (คัน)          ทางบก  ...  28325020.0  29615013.0
# 4     ขนคน (คัน)          ทางบก  ...  46996660.0  47294111.0
# 5     ขนคน (คัน)          ทางบก  ...         NaN         NaN
# 6      ขนคน (คน)          ทางบก  ...    108037.0    104032.0
# 7      ขนคน (คน)          ทางบก  ...         NaN         NaN
# 8      ขนคน (คน)          ทางบก  ...  29672244.0  29019427.0
# 9      ขนคน (คน)          ทางบก  ...  25368180.0  24993204.0
# 10    ขนคน (คัน)          ทางบก  ...         NaN         NaN
# 11    ขนคน (คัน)          ทางบก  ...         NaN         NaN
# 12     ขนคน (คน)         ทางน้ำ  ...         NaN         NaN
# 13     ขนคน (คน)         ทางน้ำ  ...    771668.0    766378.0
# ...

# %%
data1_df.columns
# Out:
# Index(['ขนคน/ขนสินค้า', 'โหมดการเดินทาง', 'รูปแบบการเดินทาง',
#        'สาธารณะ/ส่วนบุคคล', 'หน่วยงาน', 'ยานพาหนะ/ท่า', 'ม.ค. 2562',
#        'ก.พ. 2562', 'มี.ค. 2562', 'เม.ย. 2562', 'พ.ค. 2562', 'มิ.ย. 2562',
#        'ก.ค. 2562', 'ส.ค. 2562', 'ก.ย. 2562', 'ต.ค. 2562', 'พ.ย. 2562',
#        'ธ.ค. 2562'],
#       dtype='object')

# %%
data1_df_don_muang_airport = data1_df[data1_df['ยานพาหนะ/ท่า']=='ท่าอากาศยานดอนเมือง ขาออกประเทศ']
data1_df_don_muang_airport
# Out:
#    ขนคน/ขนสินค้า โหมดการเดินทาง  ... พ.ย. 2562 ธ.ค. 2562
# 35     ขนคน (คน)       ทางอากาศ  ...  676655.0  744031.0
#
# [1 rows x 18 columns]

# %%
data1_df_don_muang_airport['2020-03-25']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2020-03-25'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-96d0aa6d9b86> in <module>()
# ...

# %%
data1_df[data1_df['ยานพาหนะ/ท่า']=='ท่าอากาศยานดอนเมือง ขาออกประเทศ']['2020-03-25']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '2020-03-25'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-663fa8490ee4> in <module>()
# ...

# %%
Q4_2 = data2_df = pd.read_excel('/content/passenger-covid19.xlsx',sheet_name='Data63-64')
Q4_2
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-a94f91dabe1a> in <module>()
# ----> 1 Q4_2 = data2_df = pd.read_excel('/content/passenger-covid19.xlsx',sheet_name='Data63-64')
#       2 Q4_2
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols)
#     302
# ...

# %% [markdown]
# ###เฉลยตามอาจารย์

# %%
import pandas as pd

# %%
Q4 = data2_df = pd.read_excel('/content/passenger-covid19.xlsx',sheet_name='Data63-64')
Q4
# Out:
#    ขนคน/ขนสินค้า โหมดการเดินทาง  ... 2021-03-14 00:00:00 2021-03-15 00:00:00
# 0      ขนคน (คน)          ทางบก  ...             58371.0             52503.0
# 1      ขนคน (คน)          ทางบก  ...                 NaN                 NaN
# 2      ขนคน (คน)          ทางบก  ...             12455.0             16063.0
# 3     ขนคน (คัน)          ทางบก  ...            870772.0            920334.0
# 4     ขนคน (คัน)          ทางบก  ...           1045273.0           1110239.0
# 5     ขนคน (คัน)          ทางบก  ...           1192083.0           1534842.0
# 6     ขนคน (คัน)          ทางบก  ...           1211478.0           1590117.0
# 7     ขนคน (คัน)          ทางบก  ...                 NaN                 NaN
# 8      ขนคน (คน)          ทางบก  ...              3798.0              6490.0
# 9      ขนคน (คน)          ทางบก  ...                 NaN                 NaN
# 10     ขนคน (คน)          ทางบก  ...            565401.0            739435.0
# ...

# %%
from datetime import datetime

# %%
Q4.columns = [i.strftime('%Y-%m-%d') if isinstance(i, datetime) else i for i in Q4.columns]
Q4
# Out:
#    ขนคน/ขนสินค้า โหมดการเดินทาง  ... 2021-03-14 2021-03-15
# 0      ขนคน (คน)          ทางบก  ...    58371.0    52503.0
# 1      ขนคน (คน)          ทางบก  ...        NaN        NaN
# 2      ขนคน (คน)          ทางบก  ...    12455.0    16063.0
# 3     ขนคน (คัน)          ทางบก  ...   870772.0   920334.0
# 4     ขนคน (คัน)          ทางบก  ...  1045273.0  1110239.0
# 5     ขนคน (คัน)          ทางบก  ...  1192083.0  1534842.0
# 6     ขนคน (คัน)          ทางบก  ...  1211478.0  1590117.0
# 7     ขนคน (คัน)          ทางบก  ...        NaN        NaN
# 8      ขนคน (คน)          ทางบก  ...     3798.0     6490.0
# 9      ขนคน (คน)          ทางบก  ...        NaN        NaN
# 10     ขนคน (คน)          ทางบก  ...   565401.0   739435.0
# 11     ขนคน (คน)          ทางบก  ...   114120.0   129740.0
# 12     ขนคน (คน)          ทางบก  ...        NaN        NaN
# 13    ขนคน (คัน)          ทางบก  ...        NaN        NaN
# 14    ขนคน (คัน)          ทางบก  ...        NaN        NaN
# ...

# %%
Q4.columns
# Out:
# Index(['ขนคน/ขนสินค้า', 'โหมดการเดินทาง', 'รูปแบบการเดินทาง',
#        'สาธารณะ/ส่วนบุคคล', 'หน่วยงาน', 'ยานพาหนะ/ท่า', '2020-01-01',
#        '2020-01-02', '2020-01-03', '2020-01-04',
#        ...
#        '2021-03-06', '2021-03-07', '2021-03-08', '2021-03-09', '2021-03-10',
#        '2021-03-11', '2021-03-12', '2021-03-13', '2021-03-14', '2021-03-15'],
#       dtype='object', length=446)

# %%
Q4_don_muang_airport = Q4[Q4['ยานพาหนะ/ท่า']=='ท่าอากาศยานดอนเมือง ขาออกประเทศ']
Q4_don_muang_airport
# Out:
#    ขนคน/ขนสินค้า โหมดการเดินทาง  ... 2021-03-14 2021-03-15
# 38     ขนคน (คน)       ทางอากาศ  ...        1.0        1.0
#
# [1 rows x 446 columns]

# %%
Q4_don_muang_airport['2020-03-25']
# Out:
# 38    96.0
# Name: 2020-03-25, dtype: float64

# %%
Q4[Q4['ยานพาหนะ/ท่า']=='ท่าอากาศยานดอนเมือง ขาออกประเทศ']['2020-03-25']
# Out:
# 38    96.0
# Name: 2020-03-25, dtype: float64

# %% [markdown]
# ### Working with datetime
#
# https://towardsdatascience.com/working-with-datetime-in-pandas-dataframe-663f7af6c587
#
# https://realpython.com/python-datetime/

# %%
Q4_2 = data2_df = pd.read_excel('/content/passenger-covid19.xlsx',sheet_name='Data63-64')
Q4_2
# Out:
#    ขนคน/ขนสินค้า โหมดการเดินทาง  ... 2021-03-14 00:00:00 2021-03-15 00:00:00
# 0      ขนคน (คน)          ทางบก  ...             58371.0             52503.0
# 1      ขนคน (คน)          ทางบก  ...                 NaN                 NaN
# 2      ขนคน (คน)          ทางบก  ...             12455.0             16063.0
# 3     ขนคน (คัน)          ทางบก  ...            870772.0            920334.0
# 4     ขนคน (คัน)          ทางบก  ...           1045273.0           1110239.0
# 5     ขนคน (คัน)          ทางบก  ...           1192083.0           1534842.0
# 6     ขนคน (คัน)          ทางบก  ...           1211478.0           1590117.0
# 7     ขนคน (คัน)          ทางบก  ...                 NaN                 NaN
# 8      ขนคน (คน)          ทางบก  ...              3798.0              6490.0
# 9      ขนคน (คน)          ทางบก  ...                 NaN                 NaN
# 10     ขนคน (คน)          ทางบก  ...            565401.0            739435.0
# ...

# %%
Q4_2.columns
# Out:
# Index([    'ขนคน/ขนสินค้า',    'โหมดการเดินทาง',  'รูปแบบการเดินทาง',
#        'สาธารณะ/ส่วนบุคคล',          'หน่วยงาน',      'ยานพาหนะ/ท่า',
#        2020-01-01 00:00:00, 2020-01-02 00:00:00, 2020-01-03 00:00:00,
#        2020-01-04 00:00:00,
#        ...
#        2021-03-06 00:00:00, 2021-03-07 00:00:00, 2021-03-08 00:00:00,
#        2021-03-09 00:00:00, 2021-03-10 00:00:00, 2021-03-11 00:00:00,
#        2021-03-12 00:00:00, 2021-03-13 00:00:00, 2021-03-14 00:00:00,
#        2021-03-15 00:00:00],
#       dtype='object', length=446)

# %%
from datetime import date,datetime

# %%
datetime(day=25,month=3,year=2020)
# Out:
# datetime.datetime(2020, 3, 25, 0, 0)

# %%
Q4_2[Q4_2['ยานพาหนะ/ท่า']=='ท่าอากาศยานดอนเมือง ขาออกประเทศ'][datetime(day=25,month=3,year=2020)]
# Out:
# 38    96.0
# Name: 2020-03-25 00:00:00, dtype: float64
